# %% [markdown]
# **The __init__() Function**

# %%
class Cars:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

c1 = Cars("Bmw", "m5")

print(c1.brand)
print(c1.model)
# Out:
# Bmw
# m5

# %%
from binascii import crc32
class Cars:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

c1 = Cars("Bmw", "m5")
c2 = Cars("Toyota", "Camry")
c3 = Cars("Honda", "Civic")

print(c1.brand)
print(c1.model)
# Out:
# Bmw
# m5

# %%
print(c2.brand)
print(c2.model)
# Out:
# Toyota
# Camry

# %%
print(c3.brand)
print(c3.model)
# Out:
# Honda
# Civic

# %% [markdown]
# **WITH the __str__() function:**

# %%
class Cars:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def __str__(self):
    return f"{self.brand} ({self.model})"

c1 = Cars("Bmw", "m5")
c2 = Cars("Toyota", "Camry")
c3 = Cars("Honda", "Civic")

print(c1)
print(c2)
print(c3)
# Out:
# Bmw (m5)
# Toyota (Camry)
# Honda (Civic)

# %% [markdown]
# **prints a greeting, and execute**

# %%
class Cars:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model
    print("a new object has been created :")

c1 = Cars("Bmw", "m5")
print(c1.brand)
print(c1.model)
# Out:
# a new object has been created :
# Bmw
# m5

# %%
c3 = Cars("Honda", "Civic")
print(c3.brand)
print(c3.model)
# Out:
# a new object has been created :
# Honda
# Civic

# %%
class Cars:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model
    print("a new object has been created :" + self.brand, self.model )

c1 = Cars("Bmw", "m5")
# Out:
# a new object has been created :Bmw m5

# %%
c1.brand = "M4"
print(c1.brand)
# Out:
# M4

# %% [markdown]
# **------------**

# %%
class Account:
  def __init__(self, balance, acc):
    self.balance = balance
    self.acc = acc

  def debit(self, amount):
    self.balance -= amount
    print("Rs", amount, "was debited")
    print("Your current balance is Rs", self.balance)

  def credit(self, amount):
    self.balance += amount
    print("Rs", amount, "was credited")
    print("Your current balance is Rs", self.balance)

  def get_balance(self):
    return self.balance

ac1 = Account(5000, 456145)
ac1.debit(1000)
ac1.get_balance()
# Out:
# Rs 1000 was debited
# Your current balance is Rs 4000
# 4000

# %%
ac1.credit(10000)
# Out:
# Rs 10000 was credited
# Your current balance is Rs 18500

# %%
ac1.debit(5500)
# Out:
# Rs 5500 was debited
# Your current balance is Rs 13000
